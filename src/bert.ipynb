# %%
# !git clone -b preprocess_BERT https://FirstKohi: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@github.com/AIVIETNAM-AIO-LOP3Zs/AIO_NewsClassification.git
# Out:
# Cloning into 'AIO_NewsClassification'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 114 (delta 21), reused 102 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 7.09 MiB | 22.75 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/entertainment/
#   inflating: __MACOSX/data/._entertainment
#    creating: data/business/
#   inflating: __MACOSX/data/._business
#    creating: data/sport/
#   inflating: __MACOSX/data/._sport
#    creating: data/politics/
#   inflating: __MACOSX/data/._politics
#    creating: data/tech/
#   inflating: __MACOSX/data/._tech
#   inflating: data/entertainment/289.txt
#   inflating: __MACOSX/data/entertainment/._289.txt
#   inflating: data/entertainment/262.txt
#   inflating: __MACOSX/data/entertainment/._262.txt
#   inflating: data/entertainment/276.txt
#   inflating: __MACOSX/data/entertainment/._276.txt
#   inflating: data/entertainment/060.txt
#   inflating: __MACOSX/data/entertainment/._060.txt
#   inflating: data/entertainment/074.txt
#   inflating: __MACOSX/data/entertainment/._074.txt
#   inflating: data/entertainment/048.txt
#   inflating: __MACOSX/data/entertainment/._048.txt
#   inflating: data/entertainment/114.txt
# ...

# %%
# %cd /content/AIO_NewsClassification/src/
# %run bert_classification_final.ipynb
# Out:
# /content/AIO_NewsClassification/src
#                                                 text     label
# 0  Tsunami cost hits Jakarta shares\n\nThe stock ...  business
# 1  Circuit City gets takeover offer\n\nCircuit Ci...  business
# 2  Fed warns of more US rate rises\n\nThe US look...  business
# 3  Firms pump billions into pensions\n\nEmployers...  business
# 4  Markets fall on weak dollar fears\n\nRising oi...  business
# label
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64
# (2225, 2)
# ['business' 'entertainment' 'politics' 'sport' 'tech']
#       label  label_id
# 0  business         0
# 1  business         0
# 2  business         0
# 3  business         0
# 4  business         0
# 1780 222 223
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...
